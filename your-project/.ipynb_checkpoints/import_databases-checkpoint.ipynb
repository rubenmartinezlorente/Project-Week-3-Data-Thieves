# %% [markdown]
# # Import databases from our local folder to SQL

# %%
# Libraries
import pandas as pd
from sqlalchemy import create_engine
import pymysql

# %%
##CONNECTION
driver = 'mysql+pymysql'
ip = '127.0.0.1'
username = 'root'
password = 'root'
db = 'Project2_Barcelona'
connection_string  = f'{driver}://{username}:{password}@{ip}/{db}'

# %% [markdown]
# # **Request to PUNK IPA API**

# %%
# import libraries here

import requests
import pandas as pd
import json

# your code here
PUNKIPA = 'https://api.punkapi.com/v2/beers'

response = requests.get(PUNKIPA)
beer = response.json()
#print(json.dumps(beer[0], indent=6))   
beer_df = pd.DataFrame(beer)
newbeer = beer_df[['name','abv','tagline','srm','ebc','food_pairing','ingredients','ph','method']]

newbeer
# Out:
#                                    name    abv  \
# 0                                  Buzz   4.50
# 1                         Trashy Blonde   4.10
# 2   Berliner Weisse With Yuzu - B-Sides   4.20
# 3                          Pilsen Lager   6.30
# 4                    Avery Brown Dredge   7.20
# 5                        Electric India   5.20
# 6                                 AB:12  11.20
# 7                            Fake Lager   4.70
# 8                                 AB:07  12.50
# 9                            Bramling X   7.50
# 10                       Misspent Youth   7.30
# 11                        Arcade Nation   5.30
# 12                             Movember   4.50
# 13                            Alpha Dog   4.50
# 14                            Mixtape 8  14.50
# 15                     Libertine Porter   6.10
# 16                                AB:06  11.20
# 17        Russian Doll – India Pale Ale   6.00
# 18         Hello My Name Is Mette-Marit   8.20
# 19                             Rabiator  10.27
# 20                            Vice Bier   4.30
# 21          Devine Rebel (w/ Mikkeller)  12.50
# 22                                Storm   8.00
# 23                   The End Of History  55.00
# 24                            Bad Pixie   4.70
#
#                                               tagline    srm    ebc  \
# 0                           A Real Bitter Experience.   10.0   20.0
# 1                              You Know You Shouldn't   15.0   15.0
# 2                    Japanese Citrus Berliner Weisse.    4.0    8.0
# 3                           Unleash the Yeast Series.   15.0   30.0
# 4                         Bloggers' Imperial Pilsner.    5.0   10.0
# 5                               Vibrant Hoppy Saison.    7.5   15.0
# 6                         Imperial Black Belgian Ale.   40.0   80.0
# 7                                   Bohemian Pilsner.    6.0   12.0
# 8                        Whisky Cask-Aged Scotch Ale.   42.0   84.0
# 9                       Single Hop IPA Series - 2011.   11.0   22.0
# 10                           Milk & Honey Scotch Ale.   60.0  120.0
# 11                                Seasonal Black IPA.  100.0  200.0
# 12                             Moustache-Worthy Beer.   70.0  140.0
# 13                               Existential Red Ale.   31.0   62.0
# 14  An Epic Fusion Of Old Belgian, American New Wa...   20.0   40.0
# 15                      Dry-Hopped Aggressive Porter.  109.5  219.0
# 16                                Imperial Black IPA.   35.0   70.0
# 17                                  Nesting Hop Bomb.   12.5   25.0
# 18                            Lingonberry Double IPA.    NaN    NaN
# 19                                Imperial Wheat Beer   12.0   24.0
# 20                                  Hoppy Wheat Bier.   15.0   30.0
# 21                              Oak-aged Barley Wine.   18.0   36.0
# 22                             Islay Whisky Aged IPA.    6.0   12.0
# 23                        The World's Strongest Beer.    NaN    NaN
# 24                                 Spiced Wheat Beer.    4.0    8.0
#
#                                          food_pairing  \
# 0   [Spicy chicken tikka masala, Grilled chicken q...
# 1   [Fresh crab with lemon, Garlic butter dipping ...
# 2   [Smoked chicken wings, Miso ramen, Yuzu cheese...
# 3   [Spicy crab cakes, Spicy cucumber and carrot T...
# 4   [Vietnamese squid salad, Chargrilled corn on t...
# 5   [Mussels with a garlic and herb sauce, Crab me...
# 6   [Tandoori lamb with pomegranate, Beef Wellingt...
# 7   [Fried crab cakes with avocado salsa, Spicy sh...
# 8   [Kedgeree, Scotch broth with sourdough bread, ...
# 9   [Warm blackberry pie, Vinegar doused fish and ...
# 10  [Roasted garlic and chilli infused camembert c...
# 11  [King prawn kebabs, Halibut with a mango and t...
# 12  [Vegetable egg scramble, Margherita pizza, Fre...
# 13  [Pastrami, Swiss and horseradish sandwich, Sha...
# 14  [Coriander & chilli crab cakes, Goats cheese s...
# 15  [Blue cheese beef burger, Glazed short ribs, C...
# 16  [Coffee dusted venison loin, Memphis-style bee...
# 17  [Spicy chicken skewers, Fish tacos with hot sa...
# 18  [Fårikål (mutton stew) with a spicy twist, F...
# 19  [Grilled portabello mushroom burger, Chicken s...
# 20  [Citrus salad with balsamic dressing, Lobster,...
# 21  [Stilton on gingerbread biscuits, Pot roasted ...
# 22          [Oysters, Hickory smoked ham, Rocky Road]
# 23  [Roasted wood pigeon with black pudding, Pan s...
# 24  [Poached sole fillet with capers, Summer fruit...
#
#                                           ingredients   ph  \
# 0   {'malt': [{'name': 'Maris Otter Extra Pale', '...  4.4
# 1   {'malt': [{'name': 'Maris Otter Extra Pale', '...  4.4
# 2   {'malt': [{'name': 'Propino Pale Malt', 'amoun...  3.2
# 3   {'malt': [{'name': 'Extra Pale', 'amount': {'v...  4.4
# 4   {'malt': [{'name': 'Lager Malt', 'amount': {'v...  4.4
# 5   {'malt': [{'name': 'Extra Pale', 'amount': {'v...  4.4
# 6   {'malt': [{'name': 'Extra Pale', 'amount': {'v...  5.3
# 7   {'malt': [{'name': 'Extra Pale', 'amount': {'v...  4.4
# 8   {'malt': [{'name': 'Munich', 'amount': {'value...  5.6
# 9   {'malt': [{'name': 'Extra Pale', 'amount': {'v...  4.4
# 10  {'malt': [{'name': 'Pale Ale', 'amount': {'val...  4.4
# 11  {'malt': [{'name': 'Pale Ale', 'amount': {'val...  4.2
# 12  {'malt': [{'name': 'Maris Otter Extra Pale', '...  5.2
# 13  {'malt': [{'name': 'Maris Otter Extra Pale', '...  4.4
# 14  {'malt': [{'name': 'Pale Ale - Tipple', 'amoun...  4.4
# 15  {'malt': [{'name': 'Extra Pale - Spring Blend'...  4.4
# 16  {'malt': [{'name': 'Pale Ale', 'amount': {'val...  NaN
# 17  {'malt': [{'name': 'Extra Pale', 'amount': {'v...  5.2
# 18  {'malt': [{'name': 'Extra Pale', 'amount': {'v...  4.4
# 19  {'malt': [{'name': 'Extra Pale', 'amount': {'v...  4.4
# 20  {'malt': [{'name': 'Extra Pale', 'amount': {'v...  4.0
# 21  {'malt': [{'name': 'Extra Pale', 'amount': {'v...  4.4
# 22  {'malt': [{'name': 'Extra Pale', 'amount': {'v...  4.4
# 23  {'malt': [{'name': 'Extra Pale', 'amount': {'v...  4.4
# 24  {'malt': [{'name': 'Wheat', 'amount': {'value'...  4.4
#
#                                                method
# 0   {'mash_temp': [{'temp': {'value': 64, 'unit': ...
# 1   {'mash_temp': [{'temp': {'value': 69, 'unit': ...
# 2   {'mash_temp': [{'temp': {'value': 60, 'unit': ...
# 3   {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 4   {'mash_temp': [{'temp': {'value': 66, 'unit': ...
# 5   {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 6   {'mash_temp': [{'temp': {'value': 69, 'unit': ...
# 7   {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 8   {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 9   {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 10  {'mash_temp': [{'temp': {'value': 67, 'unit': ...
# 11  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 12  {'mash_temp': [{'temp': {'value': 68, 'unit': ...
# 13  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 14  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 15  {'mash_temp': [{'temp': {'value': 68, 'unit': ...
# 16  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 17  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 18  {'mash_temp': [{'temp': {'value': 66, 'unit': ...
# 19  {'mash_temp': [{'temp': {'value': 64, 'unit': ...
# 20  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 21  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 22  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 23  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 24  {'mash_temp': [{'temp': {'value': 67, 'unit': ...

# %%
newbeer['method'].iloc[0]
# Out:
# {'mash_temp': [{'temp': {'value': 64, 'unit': 'celsius'}, 'duration': 75}],
#  'fermentation': {'temp': {'value': 19, 'unit': 'celsius'}},
#  'twist': None}

# %%
newbeer['food_pairing'] = newbeer['food_pairing'].apply(lambda x: ','.join(x))
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
newbeer['food_pairing'].value_counts()
# Out:
# Blue cheese beef burger,Glazed short ribs,Chocolate cake                                                          1
# Poached sole fillet with capers,Summer fruit salad,Banana split                                                   1
# Coffee dusted venison loin,Memphis-style beef short ribs,Chocolate orange brownies                                1
# Grilled portabello mushroom burger,Chicken sausages with creamy mash,Caramel and banana meringue pie              1
# Warm blackberry pie,Vinegar doused fish and chips,Aromatic korma curry with lemon and garlic naan                 1
# Roasted wood pigeon with black pudding,Pan seared venison fillet with juniper sauce,Apricot coconut cake          1
# Stilton on gingerbread biscuits,Pot roasted artichokes,Lamb chops with caramelised figs                           1
# Smoked chicken wings,Miso ramen,Yuzu cheesecake                                                                   1
# Vietnamese squid salad,Chargrilled corn on the cob with paprika butter,Strawberry and rhubarb pie                 1
# Pastrami,Swiss and horseradish sandwich,Sharp cheddar cheese and onion/ raisin chutney,Peanut brittle             1
# King prawn kebabs,Halibut with a mango and tomato salad,Mint chocloate ice cream                                  1
# Spicy chicken skewers,Fish tacos with hot sauce,Lemon pound cake with a ice sugar glaze                           1
# Vegetable egg scramble,Margherita pizza,Fresh berry crisp tart                                                    1
# Fresh crab with lemon,Garlic butter dipping sauce,Goats cheese salad,Creamy lemon bar doused in powdered sugar    1
# Fårikål (mutton stew) with a spicy twist,Fenalår (salted cured lamb),Krumkake with lingonberry jam             1
# Tandoori lamb with pomegranate,Beef Wellington with a red wine jus,Raspberry chocolate torte                      1
# Oysters,Hickory smoked ham,Rocky Road                                                                             1
# Kedgeree,Scotch broth with sourdough bread,Clootie dumpling                                                       1
# Spicy chicken tikka masala,Grilled chicken quesadilla,Caramel toffee cake                                         1
# Citrus salad with balsamic dressing,Lobster,Ginger and orange cookies                                             1
# Spicy crab cakes,Spicy cucumber and carrot Thai salad,Sweet filled dumplings                                      1
# Roasted garlic and chilli infused camembert cheese,Korean style chicken wings,Chocolate milk shake                1
# Fried crab cakes with avocado salsa,Spicy shredded pork roll with hot dipping sauce,Key lime pie                  1
# Coriander & chilli crab cakes,Goats cheese salad with walnuts, radish and blood orange,Pistachio cake             1
# Mussels with a garlic and herb sauce,Crab melt sandwich,Shortbread cookies                                        1
# Name: food_pairing, dtype: int64

# %%
newbeer['abv'].plot(kind='box')
