# %% [markdown]
# ### 1. What kind of categories of beers exists?

# %% [markdown]
# First let's read the csv of beers and categories

# %%
import pandas as pd

beers = pd.read_csv('NEW_DATA/beers_new.csv')

categories = pd.read_csv('NEW_DATA/categories_new.csv')

breweries = pd.read_csv('NEW_DATA/brewery_new.csv')

# %%
beers.head()
beers = beers.astype({'cat_id': int, 'brewery_id': int})

# %%
beers
# Out:
#       brewery_id                               name  cat_id  style_id  abv
# 0            812                        Hocus Pocus      11     116.0  4.5
# 1           1385                      Winter Warmer       1      13.0  5.2
# 2           1099                      Oatmeal Stout       3      42.0  5.0
# 3           1099                     Imperial Stout       3      42.0  7.0
# 4           1023                 Wiesen Edel Weisse       4      50.0  6.2
# ...          ...                                ...     ...       ...  ...
# 2518        1417                      Watershed IPA       3      30.0  7.1
# 2519        1087          Estrella Levante Especial       9     106.0  5.4
# 2520        1087  Estrella Levante Sin 0.0% Alcohol       9     106.0  1.0
# 2521        1419            Koshihikari Echigo Beer      11     132.0  5.0
# 2522        1421                         The Public       3      26.0  6.0
#
# [2523 rows x 5 columns]

# %%
breweries.head()
# Out:
#    id                                               name  \
# 0   1                              (512) Brewing Company
# 1   2                        21st Amendment Brewery Cafe
# 2   3  3 Fonteinen Brouwerij Ambachtelijke Geuzestekerij
# 3   4                                       Aass Brewery
# 4   5                                    Abbaye de Leffe
#
#                          address1           city           state  \
# 0                 407 Radam, F200         Austin           Texas
# 1               563 Second Street  San Francisco      California
# 2                   Hoogstraat 2A        Beersel  Vlaams Brabant
# 3  Ole Steensgt. 10 Postboks 1530        Drammen             NaN
# 4                          Dinant         Dinant           Namur
#
#          country
# 0  United States
# 1  United States
# 2        Belgium
# 3         Norway
# 4        Belgium

# %%
categories
# Out:
#     id                cat_name
# 0    1             British Ale
# 1    2               Irish Ale
# 2    3      North American Ale
# 3    4              German Ale
# 4    5  Belgian and French Ale
# 5    6       International Ale
# 6    7            German Lager
# 7    8    North American Lager
# 8    9             Other Lager
# 9   10     International Lager
# 10  11             Other Style

# %%
#df1.merge(df2, left_on='lkey', right_on='rkey')
dataset1 = beers.merge(breweries, left_on='brewery_id', right_on ='id')

# %%
dataset2 = dataset1.merge(categories, left_on='cat_id', right_on ='id')

# %%
dataset2 = dataset2.drop(['id_x', 'id_y', 'address1', 'state'], axis=1)

# %%
dataset2.head()
# Out:
#    brewery_id                    name_x  cat_id  style_id  abv  \
# 0         812               Hocus Pocus      11     116.0  4.5
# 1         812            Feast of Fools      11     121.0  5.3
# 2         812                     Wacko      11     121.0  4.5
# 3        1099  Winter Welcome 2008-2009      11     141.0  6.0
# 4        1023          Schneider Weisse      11     116.0  5.4
#
#                                               name_y              city  \
# 0                                          Magic Hat  South Burlington
# 1                                          Magic Hat  South Burlington
# 2                                          Magic Hat  South Burlington
# 3               Samuel Smith Old Brewery (Tadcaster)         Tadcaster
# 4  Private Weissbierbrauerei G. Schneider & Sohn ...           Kelheim
#
#           country     cat_name
# 0   United States  Other Style
# 1   United States  Other Style
# 2   United States  Other Style
# 3  United Kingdom  Other Style
# 4         Germany  Other Style

# %%
dataset2.astype({'style_id': int})
# Out:
#       brewery_id                             name_x  cat_id  style_id   abv  \
# 0            812                        Hocus Pocus      11       116  4.50
# 1            812                     Feast of Fools      11       121  5.30
# 2            812                              Wacko      11       121  4.50
# 3           1099           Winter Welcome 2008-2009      11       141  6.00
# 4           1023                   Schneider Weisse      11       116  5.40
# ...          ...                                ...     ...       ...   ...
# 2518        1416                      Vivant Tripel       5        61  9.25
# 2519        1087           Estrella Levante Clasica       9       106  4.80
# 2520        1087          Estrella Levante Especial       9       106  5.40
# 2521        1087  Estrella Levante Sin 0.0% Alcohol       9       106  1.00
# 2522        1405                          Baltika 6       9       106  7.00
#
#                                                  name_y              city  \
# 0                                             Magic Hat  South Burlington
# 1                                             Magic Hat  South Burlington
# 2                                             Magic Hat  South Burlington
# 3                  Samuel Smith Old Brewery (Tadcaster)         Tadcaster
# 4     Private Weissbierbrauerei G. Schneider & Sohn ...           Kelheim
# ...                                                 ...               ...
# 2518                                     Brewery Vivant      Grand Rapids
# 2519                                          S.A. Damm         Barcelona
# 2520                                          S.A. Damm         Barcelona
# 2521                                          S.A. Damm         Barcelona
# 2522                                  Baltika Breweries    St. Petersburg
#
#              country                cat_name
# 0      United States             Other Style
# 1      United States             Other Style
# 2      United States             Other Style
# 3     United Kingdom             Other Style
# 4            Germany             Other Style
# ...              ...                     ...
# 2518   United States  Belgian and French Ale
# 2519           Spain             Other Lager
# 2520           Spain             Other Lager
# 2521           Spain             Other Lager
# 2522          Russia             Other Lager
#
# [2523 rows x 9 columns]

# %%
cat_popularity = dataset2['cat_name'].value_counts()
cat_popularity.head()
# Out:
# North American Ale        1073
# Belgian and French Ale     267
# North American Lager       245
# German Lager               244
# British Ale                242
# Name: cat_name, dtype: int64

# %%
categories = dataset2.groupby(['cat_name']).count()

# %%
categories
# Out:
#                         brewery_id  name_x  cat_id  style_id   abv  name_y  \
# cat_name
# Belgian and French Ale         267     267     267       267   267     267
# British Ale                    242     242     242       242   242     242
# German Ale                     107     107     107       107   107     107
# German Lager                   244     244     244       244   244     244
# Irish Ale                      141     141     141       141   141     141
# North American Ale            1073    1073    1073      1073  1073    1073
# North American Lager           245     245     245       245   245     245
# Other Lager                      4       4       4         4     4       4
# Other Style                    200     200     200       200   200     200
#
#                         city  country
# cat_name
# Belgian and French Ale   266      267
# British Ale              237      242
# German Ale               107      107
# German Lager             241      244
# Irish Ale                141      141
# North American Ale      1072     1073
# North American Lager     242      245
# Other Lager                4        4
# Other Style              196      200

# %%
#mean_res = newbeer.groupby(['srm_type']).mean().drop(['srm'], axis=1)
